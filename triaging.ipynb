# %%
import numpy as np
import ctypes
import scipy.stats as stats
from scipy.stats import wasserstein_distance
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from datagen import get_dataloader, create_file_pairs

# -------- Helper Functions --------

def reduce_float_precision(value, nmantissa):
    # Constants
    NMANTISSA = 23
    MAX_EXPONENT = 0x7f7  # corresponds to max exponent before Inf (254 in biased form)
    MIN_MANTISSA_BITS = 1

    # Convert float32 to raw bits
    float_val = ctypes.c_float(value)
    bits = ctypes.cast(ctypes.pointer(float_val), ctypes.POINTER(ctypes.c_uint32)).contents.value

    # Handle NaN and Inf (do not compress)
    if (bits & 0x7f800000) == 0x7f800000:
        return value  # Already Inf/NaN

    # If full mantissa requested, or invalid range, return original
    if nmantissa >= NMANTISSA or nmantissa <= 0:
        return value

    # Clamp to minimum mantissa
    if nmantissa < MIN_MANTISSA_BITS:
        nmantissa = MIN_MANTISSA_BITS

    # Compute shift and masks
    shift = NMANTISSA - nmantissa
    mask = (~0) << shift  # Keeps upper nmantissa bits
    round_bit = 1 << (shift - 1)

    mantissa = bits & 0x007fffff
    exponent = (bits >> 23) & 0xff

    # Create a mask for vmax check (from C++)
    vmax = (MAX_EXPONENT << 23) | (0x007fffff ^ round_bit)

    # Perform rounding if it won't cause overflow
    if (bits & 0x7fffffff) < vmax:
        mantissa += round_bit

    # Apply mantissa mask (truncate lower bits)
    mantissa &= mask

    # Reassemble final bits
    compressed_bits = (bits & 0xff800000) | mantissa  # keep sign and exponent

    # Convert bits back to float32
    compressed_uint = ctypes.c_uint32(compressed_bits)
    compressed_float = ctypes.cast(ctypes.pointer(compressed_uint), ctypes.POINTER(ctypes.c_float)).contents.value

    return compressed_float

def float_to_bits(val):
    """Convert a float32 to its raw 32-bit representation."""
    float_val = ctypes.c_float(val)
    bits = ctypes.cast(ctypes.pointer(float_val), ctypes.POINTER(ctypes.c_uint32)).contents.value
    return bits

def print_float_bits(val, label="Value"):
    bits = float_to_bits(val)
    sign = (bits >> 31) & 0x1
    exponent = (bits >> 23) & 0xff
    mantissa = bits & 0x7fffff
    return f"{label}: {val:.6f} | Sign: {sign} Exponent: {exponent:08b} Mantissa: {mantissa:023b}"


def summary_stats(x):
    return {
        "mean": np.mean(x),
        "std": np.std(x),
        "skew": stats.skew(x),
        "kurtosis": stats.kurtosis(x),
    }

def kl_divergence(p, q, bins=100):
    """KL divergence between histograms p and q"""
    p_hist, _ = np.histogram(p, bins=bins, density=True)
    q_hist, _ = np.histogram(q, bins=bins, density=True)
    p_hist += 1e-10; q_hist += 1e-10  # avoid div by zero
    return stats.entropy(p_hist, q_hist)

def js_divergence(p, q, bins=100):
    """Jensen-Shannon divergence"""
    p_hist, _ = np.histogram(p, bins=bins, density=True)
    q_hist, _ = np.histogram(q, bins=bins, density=True)
    m = 0.5 * (p_hist + q_hist)
    return 0.5 * (stats.entropy(p_hist, m) + stats.entropy(q_hist, m))

def mmd_rbf(x, y, gamma=1.0):
    """Maximum Mean Discrepancy with RBF kernel"""

    def kernel(a, b):
        sq_dists = np.sum(a**2, 1).reshape(-1,1) + np.sum(b**2,1) - 2*np.dot(a, b.T)
        sq_dists = np.maximum(sq_dists, 0)  # clamp negatives from precision errors
        K = np.exp(-gamma * np.clip(sq_dists, 0, 1e6))  # prevent overflow
        return K
    
    
    x = x[:min(5000, len(x))].reshape(-1,1)
    y = y[:min(5000, len(y))].reshape(-1,1)
    Kxx = kernel(x, x).mean()
    Kyy = kernel(y, y).mean()
    Kxy = kernel(x, y).mean()
    return Kxx + Kyy - 2*Kxy

def classifier_test(x, y):
    """Train/test classifier to detect original vs compressed"""
    X = np.concatenate([x.reshape(-1,1), y.reshape(-1,1)])
    labels = np.array([0]*len(x) + [1]*len(y))
    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.3, stratify=labels)
    clf = LogisticRegression(max_iter=1000).fit(X_train, y_train)
    y_score = clf.predict_proba(X_test)[:,1]
    auc = roc_auc_score(y_test, y_score)
    return auc

# -------- Main Triage Pipeline --------

def triage(original, compressed, name="Condition"):
    print(f"\n=== {name} ===")

    # Step 1: Summary
    print("Summary (original):", summary_stats(original))
    print("Summary (compressed):", summary_stats(compressed))

    # Step 2: Divergences
    print("KL divergence:", kl_divergence(original, compressed))
    print("JS divergence:", js_divergence(original, compressed))
    print("Wasserstein:", wasserstein_distance(original, compressed))
    print("MMD:", mmd_rbf(original, compressed))

    # Step 3: Hypothesis tests
    ks_stat, ks_p = stats.ks_2samp(original, compressed)
    print(f"KS test: stat={ks_stat:.4f}, p={ks_p:.4f}")

    # Step 4: Classifier
    auc = classifier_test(original, compressed)
    print("Classifier AUC (0.5 = indistinguishable):", auc)

# %%
branch = "AnalysisElectronsAuxDyn"
varnames = ["pt"]
global_min=712
global_max=716800
dataloader = get_dataloader(branch=branch, varnames=varnames, hist=False, range=(global_min, global_max), full_sample_mode=True, batch_size=1, shuffle=False)

# %%
for compressed, residual in dataloader:
    compressed = compressed.squeeze()
    residual = residual.squeeze()
    original = compressed + residual
    for nmantissa in [2, 3, 5, 10, 15]:
        compressed_new = np.array([reduce_float_precision(i, nmantissa=nmantissa) for i in original])
        for i in range(3):
            orig_bits = print_float_bits(original[i])
            comp_bits = print_float_bits(compressed_new[i])
            print(f"Value {i}:")
            print(f"  Original:   {original[i]:.6f}, {orig_bits}")
            print(f"  Compressed: {compressed_new[i]:.6f}, {comp_bits}")
        triage(original.numpy(), compressed_new, name=f"Compressed vs Original, nmantissa={nmantissa}")
        print("-"*40)
# Out:
# Value 0:
#   Original:   4610.336914, Value: 4610.336914 | Sign: 0 Exponent: 10001011 Mantissa: 00100000001001010110010
#   Compressed: 5120.000000, Value: 5120.000000 | Sign: 0 Exponent: 10001011 Mantissa: 01000000000000000000000
# Value 1:
#   Original:   4209.977539, Value: 4209.977539 | Sign: 0 Exponent: 10001011 Mantissa: 00000111000111111010010
#   Compressed: 4096.000000, Value: 4096.000000 | Sign: 0 Exponent: 10001011 Mantissa: 00000000000000000000000
# Value 2:
#   Original:   3048.412354, Value: 3048.412354 | Sign: 0 Exponent: 10001010 Mantissa: 01111101000011010011001
#   Compressed: 3072.000000, Value: 3072.000000 | Sign: 0 Exponent: 10001010 Mantissa: 10000000000000000000000
#
# === Compressed vs Original, nmantissa=2 ===
# Summary (original): {'mean': np.float32(17932.43), 'std': np.float32(24870.092), 'skew': np.float64(5.637500286102295), 'kurtosis': np.float32(79.48475)}
# Summary (compressed): {'mean': np.float64(17352.527797185347), 'std': np.float64(24366.59262821769), 'skew': np.float64(5.5684552339744835), 'kurtosis': np.float64(74.40370780755067)}
# KL divergence: 0.948151451964702
# JS divergence: 0.046244677133037614
# Wasserstein: 1113.8016094859224
# MMD: 0.0715711688213769
# KS test: stat=0.1024, p=0.0000
# Classifier AUC (0.5 = indistinguishable): 0.5108681505916975
# ----------------------------------------
# Value 0:
#   Original:   4610.336914, Value: 4610.336914 | Sign: 0 Exponent: 10001011 Mantissa: 00100000001001010110010
#   Compressed: 4608.000000, Value: 4608.000000 | Sign: 0 Exponent: 10001011 Mantissa: 00100000000000000000000
# Value 1:
#   Original:   4209.977539, Value: 4209.977539 | Sign: 0 Exponent: 10001011 Mantissa: 00000111000111111010010
#   Compressed: 4096.000000, Value: 4096.000000 | Sign: 0 Exponent: 10001011 Mantissa: 00000000000000000000000
# Value 2:
#   Original:   3048.412354, Value: 3048.412354 | Sign: 0 Exponent: 10001010 Mantissa: 01111101000011010011001
#   Compressed: 3072.000000, Value: 3072.000000 | Sign: 0 Exponent: 10001010 Mantissa: 10000000000000000000000
#
# === Compressed vs Original, nmantissa=3 ===
# Summary (original): {'mean': np.float32(17932.43), 'std': np.float32(24870.092), 'skew': np.float64(5.637500286102295), 'kurtosis': np.float32(79.48475)}
# Summary (compressed): {'mean': np.float64(17673.057989819343), 'std': np.float64(24763.31539071384), 'skew': np.float64(5.918772123006655), 'kurtosis': np.float64(90.61763549465512)}
# KL divergence: 0.10227509349288225
# JS divergence: 0.009134422242216014
# Wasserstein: 534.4366896500156
# MMD: 0.03606864097135903
# KS test: stat=0.0534, p=0.0000
# Classifier AUC (0.5 = indistinguishable): 0.5067518544636166
# ----------------------------------------
# Value 0:
#   Original:   4610.336914, Value: 4610.336914 | Sign: 0 Exponent: 10001011 Mantissa: 00100000001001010110010
#   Compressed: 4608.000000, Value: 4608.000000 | Sign: 0 Exponent: 10001011 Mantissa: 00100000000000000000000
# Value 1:
#   Original:   4209.977539, Value: 4209.977539 | Sign: 0 Exponent: 10001011 Mantissa: 00000111000111111010010
#   Compressed: 4224.000000, Value: 4224.000000 | Sign: 0 Exponent: 10001011 Mantissa: 00001000000000000000000
# Value 2:
#   Original:   3048.412354, Value: 3048.412354 | Sign: 0 Exponent: 10001010 Mantissa: 01111101000011010011001
#   Compressed: 3072.000000, Value: 3072.000000 | Sign: 0 Exponent: 10001010 Mantissa: 10000000000000000000000
#
# === Compressed vs Original, nmantissa=5 ===
# Summary (original): {'mean': np.float32(17932.43), 'std': np.float32(24870.092), 'skew': np.float64(5.637500286102295), 'kurtosis': np.float32(79.48475)}
# Summary (compressed): {'mean': np.float64(17880.283461423296), 'std': np.float64(24837.67646859134), 'skew': np.float64(5.637735218220938), 'kurtosis': np.float64(79.22185909154608)}
# KL divergence: 0.004477831926689184
# JS divergence: 0.0007693162788615442
# Wasserstein: 126.33490978956381
# MMD: 0.009234303126713042
# KS test: stat=0.0145, p=0.2424
# Classifier AUC (0.5 = indistinguishable): 0.49858898304522026
# ----------------------------------------
# Value 0:
#   Original:   4610.336914, Value: 4610.336914 | Sign: 0 Exponent: 10001011 Mantissa: 00100000001001010110010
#   Compressed: 4612.000000, Value: 4612.000000 | Sign: 0 Exponent: 10001011 Mantissa: 00100000010000000000000
# Value 1:
#   Original:   4209.977539, Value: 4209.977539 | Sign: 0 Exponent: 10001011 Mantissa: 00000111000111111010010
#   Compressed: 4208.000000, Value: 4208.000000 | Sign: 0 Exponent: 10001011 Mantissa: 00000111000000000000000
# Value 2:
#   Original:   3048.412354, Value: 3048.412354 | Sign: 0 Exponent: 10001010 Mantissa: 01111101000011010011001
#   Compressed: 3048.000000, Value: 3048.000000 | Sign: 0 Exponent: 10001010 Mantissa: 01111101000000000000000
#
# === Compressed vs Original, nmantissa=10 ===
# Summary (original): {'mean': np.float32(17932.43), 'std': np.float32(24870.092), 'skew': np.float64(5.637500286102295), 'kurtosis': np.float32(79.48475)}
# Summary (compressed): {'mean': np.float64(17931.862361513126), 'std': np.float64(24870.03663203113), 'skew': np.float64(5.636738591451895), 'kurtosis': np.float64(79.4573515894231)}
# KL divergence: 0.00041569602366835895
# JS divergence: 0.00010464564603341153
# Wasserstein: 3.493412857367864
# MMD: 0.00046563272717707214
# KS test: stat=0.0010, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.49539731802750675
# ----------------------------------------
# Value 0:
#   Original:   4610.336914, Value: 4610.336914 | Sign: 0 Exponent: 10001011 Mantissa: 00100000001001010110010
#   Compressed: 4610.375000, Value: 4610.375000 | Sign: 0 Exponent: 10001011 Mantissa: 00100000001001100000000
# Value 1:
#   Original:   4209.977539, Value: 4209.977539 | Sign: 0 Exponent: 10001011 Mantissa: 00000111000111111010010
#   Compressed: 4210.000000, Value: 4210.000000 | Sign: 0 Exponent: 10001011 Mantissa: 00000111001000000000000
# Value 2:
#   Original:   3048.412354, Value: 3048.412354 | Sign: 0 Exponent: 10001010 Mantissa: 01111101000011010011001
#   Compressed: 3048.437500, Value: 3048.437500 | Sign: 0 Exponent: 10001010 Mantissa: 01111101000011100000000
#
# === Compressed vs Original, nmantissa=15 ===
# Summary (original): {'mean': np.float32(17932.43), 'std': np.float32(24870.092), 'skew': np.float64(5.637500286102295), 'kurtosis': np.float32(79.48475)}
# Summary (compressed): {'mean': np.float64(17932.427796561533), 'std': np.float64(24870.081187081054), 'skew': np.float64(5.637481194911794), 'kurtosis': np.float64(79.48395189159051)}
# KL divergence: 2.2995693176184184e-14
# JS divergence: 5.552283855324505e-15
# Wasserstein: 0.09864053708110904
# MMD: 0.00019630944789345267
# KS test: stat=0.0003, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.5011715314104548
# ----------------------------------------
# Value 0:
#   Original:   5852.782227, Value: 5852.782227 | Sign: 0 Exponent: 10001011 Mantissa: 01101101110011001000010
#   Compressed: 6144.000000, Value: 6144.000000 | Sign: 0 Exponent: 10001011 Mantissa: 10000000000000000000000
# Value 1:
#   Original:   29397.679688, Value: 29397.679688 | Sign: 0 Exponent: 10001101 Mantissa: 11001011010101101011100
#   Compressed: 28672.000000, Value: 28672.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11000000000000000000000
# Value 2:
#   Original:   17538.265625, Value: 17538.265625 | Sign: 0 Exponent: 10001101 Mantissa: 00010010000010010001000
#   Compressed: 16384.000000, Value: 16384.000000 | Sign: 0 Exponent: 10001101 Mantissa: 00000000000000000000000
#
# === Compressed vs Original, nmantissa=2 ===
# Summary (original): {'mean': np.float32(24424.807), 'std': np.float32(29237.04), 'skew': np.float64(5.696889877319336), 'kurtosis': np.float32(75.839)}
# Summary (compressed): {'mean': np.float64(23532.04092808762), 'std': np.float64(28804.155986594513), 'skew': np.float64(5.471568157661618), 'kurtosis': np.float64(66.12044173607387)}
# KL divergence: 1.394543118389931
# JS divergence: 0.06730615042611508
# Wasserstein: 1618.469523542984
# MMD: 0.06476907079469306
# KS test: stat=0.0968, p=0.0000
# Classifier AUC (0.5 = indistinguishable): 0.5217107248350761
# ----------------------------------------
# Value 0:
#   Original:   5852.782227, Value: 5852.782227 | Sign: 0 Exponent: 10001011 Mantissa: 01101101110011001000010
#   Compressed: 5632.000000, Value: 5632.000000 | Sign: 0 Exponent: 10001011 Mantissa: 01100000000000000000000
# Value 1:
#   Original:   29397.679688, Value: 29397.679688 | Sign: 0 Exponent: 10001101 Mantissa: 11001011010101101011100
#   Compressed: 28672.000000, Value: 28672.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11000000000000000000000
# Value 2:
#   Original:   17538.265625, Value: 17538.265625 | Sign: 0 Exponent: 10001101 Mantissa: 00010010000010010001000
#   Compressed: 18432.000000, Value: 18432.000000 | Sign: 0 Exponent: 10001101 Mantissa: 00100000000000000000000
#
# === Compressed vs Original, nmantissa=3 ===
# Summary (original): {'mean': np.float32(24424.807), 'std': np.float32(29237.04), 'skew': np.float64(5.696889877319336), 'kurtosis': np.float32(75.839)}
# Summary (compressed): {'mean': np.float64(24019.793053754143), 'std': np.float64(29186.28858944861), 'skew': np.float64(5.8207589340892305), 'kurtosis': np.float64(78.79548873393185)}
# KL divergence: 0.06625612050879087
# JS divergence: 0.008905795338646601
# Wasserstein: 785.2969878433535
# MMD: 0.03421371056087084
# KS test: stat=0.0483, p=0.0000
# Classifier AUC (0.5 = indistinguishable): 0.5096612840863686
# ----------------------------------------
# Value 0:
#   Original:   5852.782227, Value: 5852.782227 | Sign: 0 Exponent: 10001011 Mantissa: 01101101110011001000010
#   Compressed: 5888.000000, Value: 5888.000000 | Sign: 0 Exponent: 10001011 Mantissa: 01110000000000000000000
# Value 1:
#   Original:   29397.679688, Value: 29397.679688 | Sign: 0 Exponent: 10001101 Mantissa: 11001011010101101011100
#   Compressed: 29184.000000, Value: 29184.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11001000000000000000000
# Value 2:
#   Original:   17538.265625, Value: 17538.265625 | Sign: 0 Exponent: 10001101 Mantissa: 00010010000010010001000
#   Compressed: 17408.000000, Value: 17408.000000 | Sign: 0 Exponent: 10001101 Mantissa: 00010000000000000000000
#
# === Compressed vs Original, nmantissa=5 ===
# Summary (original): {'mean': np.float32(24424.807), 'std': np.float32(29237.04), 'skew': np.float64(5.696889877319336), 'kurtosis': np.float32(75.839)}
# Summary (compressed): {'mean': np.float64(24345.610606715665), 'std': np.float64(29246.20713312596), 'skew': np.float64(5.741224745438458), 'kurtosis': np.float64(77.29077713191228)}
# KL divergence: 0.005649501935149666
# JS divergence: 0.0008335729713325008
# Wasserstein: 184.21926339371174
# MMD: 0.009221680041848514
# KS test: stat=0.0121, p=0.6895
# Classifier AUC (0.5 = indistinguishable): 0.49167905499865733
# ----------------------------------------
# Value 0:
#   Original:   5852.782227, Value: 5852.782227 | Sign: 0 Exponent: 10001011 Mantissa: 01101101110011001000010
#   Compressed: 5852.000000, Value: 5852.000000 | Sign: 0 Exponent: 10001011 Mantissa: 01101101110000000000000
# Value 1:
#   Original:   29397.679688, Value: 29397.679688 | Sign: 0 Exponent: 10001101 Mantissa: 11001011010101101011100
#   Compressed: 29392.000000, Value: 29392.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11001011010000000000000
# Value 2:
#   Original:   17538.265625, Value: 17538.265625 | Sign: 0 Exponent: 10001101 Mantissa: 00010010000010010001000
#   Compressed: 17536.000000, Value: 17536.000000 | Sign: 0 Exponent: 10001101 Mantissa: 00010010000000000000000
#
# === Compressed vs Original, nmantissa=10 ===
# Summary (original): {'mean': np.float32(24424.807), 'std': np.float32(29237.04), 'skew': np.float64(5.696889877319336), 'kurtosis': np.float32(75.839)}
# Summary (compressed): {'mean': np.float64(24424.02485948984), 'std': np.float64(29237.602377806288), 'skew': np.float64(5.697810062032247), 'kurtosis': np.float64(75.87763904324075)}
# KL divergence: 7.277883023751502e-05
# JS divergence: 1.6720487078892155e-05
# Wasserstein: 4.766797985049987
# MMD: 0.0005536069013936378
# KS test: stat=0.0012, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.5021445425360416
# ----------------------------------------
# Value 0:
#   Original:   5852.782227, Value: 5852.782227 | Sign: 0 Exponent: 10001011 Mantissa: 01101101110011001000010
#   Compressed: 5852.750000, Value: 5852.750000 | Sign: 0 Exponent: 10001011 Mantissa: 01101101110011000000000
# Value 1:
#   Original:   29397.679688, Value: 29397.679688 | Sign: 0 Exponent: 10001101 Mantissa: 11001011010101101011100
#   Compressed: 29397.500000, Value: 29397.500000 | Sign: 0 Exponent: 10001101 Mantissa: 11001011010101100000000
# Value 2:
#   Original:   17538.265625, Value: 17538.265625 | Sign: 0 Exponent: 10001101 Mantissa: 00010010000010010001000
#   Compressed: 17538.500000, Value: 17538.500000 | Sign: 0 Exponent: 10001101 Mantissa: 00010010000010100000000
#
# === Compressed vs Original, nmantissa=15 ===
# Summary (original): {'mean': np.float32(24424.807), 'std': np.float32(29237.04), 'skew': np.float64(5.696889877319336), 'kurtosis': np.float32(75.839)}
# Summary (compressed): {'mean': np.float64(24424.801482111976), 'std': np.float64(29237.01289436578), 'skew': np.float64(5.696876068089785), 'kurtosis': np.float64(75.83876327839245)}
# KL divergence: 2.4238246633044626e-14
# JS divergence: 6.101853432714322e-15
# Wasserstein: 0.13393501383991313
# MMD: 0.0002405928419596664
# KS test: stat=0.0003, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.4937754975864669
# ----------------------------------------
# /home/kanbina/code/dct_flow/.venv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   res = hypotest_fun_out(*samples, **kwds)
# Value 0:
#   Original:   3160.729736, Value: 3160.729736 | Sign: 0 Exponent: 10001010 Mantissa: 10001011000101110101101
#   Compressed: 3072.000000, Value: 3072.000000 | Sign: 0 Exponent: 10001010 Mantissa: 10000000000000000000000
# Value 1:
#   Original:   29419.267578, Value: 29419.267578 | Sign: 0 Exponent: 10001101 Mantissa: 11001011101011010001001
#   Compressed: 28672.000000, Value: 28672.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11000000000000000000000
# Value 2:
#   Original:   31330.224609, Value: 31330.224609 | Sign: 0 Exponent: 10001101 Mantissa: 11101001100010001110011
#   Compressed: 16384.000000, Value: 16384.000000 | Sign: 0 Exponent: 10001101 Mantissa: 00000000000000000000000
#
# === Compressed vs Original, nmantissa=2 ===
# Summary (original): {'mean': np.float32(30765.113), 'std': np.float32(36173.812), 'skew': np.float64(2.5236427783966064), 'kurtosis': np.float32(11.069621)}
# Summary (compressed): {'mean': np.float64(29971.259023453957), 'std': np.float64(35617.85680339119), 'skew': np.float64(2.5932016087642324), 'kurtosis': np.float64(11.664118993536446)}
# KL divergence: 1.900233003915185
# JS divergence: 0.094660207138447
# Wasserstein: 1633.0873026148079
# MMD: 0.046298780775660124
# KS test: stat=0.0607, p=0.0000
# Classifier AUC (0.5 = indistinguishable): 0.5095492426140334
# ----------------------------------------
# Value 0:
#   Original:   3160.729736, Value: 3160.729736 | Sign: 0 Exponent: 10001010 Mantissa: 10001011000101110101101
#   Compressed: 3072.000000, Value: 3072.000000 | Sign: 0 Exponent: 10001010 Mantissa: 10000000000000000000000
# Value 1:
#   Original:   29419.267578, Value: 29419.267578 | Sign: 0 Exponent: 10001101 Mantissa: 11001011101011010001001
#   Compressed: 28672.000000, Value: 28672.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11000000000000000000000
# Value 2:
#   Original:   31330.224609, Value: 31330.224609 | Sign: 0 Exponent: 10001101 Mantissa: 11101001100010001110011
#   Compressed: 30720.000000, Value: 30720.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11100000000000000000000
#
# === Compressed vs Original, nmantissa=3 ===
# Summary (original): {'mean': np.float32(30765.113), 'std': np.float32(36173.812), 'skew': np.float64(2.5236427783966064), 'kurtosis': np.float32(11.069621)}
# Summary (compressed): {'mean': np.float64(30402.726464116848), 'std': np.float64(35938.46015521944), 'skew': np.float64(2.561731738067436), 'kurtosis': np.float64(11.543948027944522)}
# KL divergence: 0.46437767214198095
# JS divergence: 0.0265752756530859
# Wasserstein: 810.3161043144171
# MMD: 0.02322773996345682
# KS test: stat=0.0312, p=0.0000
# Classifier AUC (0.5 = indistinguishable): 0.49920482050733694
# ----------------------------------------
# Value 0:
#   Original:   3160.729736, Value: 3160.729736 | Sign: 0 Exponent: 10001010 Mantissa: 10001011000101110101101
#   Compressed: 3136.000000, Value: 3136.000000 | Sign: 0 Exponent: 10001010 Mantissa: 10001000000000000000000
# Value 1:
#   Original:   29419.267578, Value: 29419.267578 | Sign: 0 Exponent: 10001101 Mantissa: 11001011101011010001001
#   Compressed: 29184.000000, Value: 29184.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11001000000000000000000
# Value 2:
#   Original:   31330.224609, Value: 31330.224609 | Sign: 0 Exponent: 10001101 Mantissa: 11101001100010001110011
#   Compressed: 31232.000000, Value: 31232.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11101000000000000000000
#
# === Compressed vs Original, nmantissa=5 ===
# Summary (original): {'mean': np.float32(30765.113), 'std': np.float32(36173.812), 'skew': np.float64(2.5236427783966064), 'kurtosis': np.float32(11.069621)}
# Summary (compressed): {'mean': np.float64(30673.288329198072), 'std': np.float64(36100.24386918583), 'skew': np.float64(2.531685431336102), 'kurtosis': np.float64(11.16940328560411)}
# KL divergence: 0.005656533103815486
# JS divergence: 0.0012145841593282276
# Wasserstein: 206.2211039237633
# MMD: 0.006117437804636096
# KS test: stat=0.0082, p=0.1149
# Classifier AUC (0.5 = indistinguishable): 0.4997166254059971
# ----------------------------------------
# Value 0:
#   Original:   3160.729736, Value: 3160.729736 | Sign: 0 Exponent: 10001010 Mantissa: 10001011000101110101101
#   Compressed: 3160.000000, Value: 3160.000000 | Sign: 0 Exponent: 10001010 Mantissa: 10001011000000000000000
# Value 1:
#   Original:   29419.267578, Value: 29419.267578 | Sign: 0 Exponent: 10001101 Mantissa: 11001011101011010001001
#   Compressed: 29424.000000, Value: 29424.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11001011110000000000000
# Value 2:
#   Original:   31330.224609, Value: 31330.224609 | Sign: 0 Exponent: 10001101 Mantissa: 11101001100010001110011
#   Compressed: 31328.000000, Value: 31328.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11101001100000000000000
#
# === Compressed vs Original, nmantissa=10 ===
# Summary (original): {'mean': np.float32(30765.113), 'std': np.float32(36173.812), 'skew': np.float64(2.5236427783966064), 'kurtosis': np.float32(11.069621)}
# Summary (compressed): {'mean': np.float64(30764.1896680867), 'std': np.float64(36174.18265167816), 'skew': np.float64(2.523777573540832), 'kurtosis': np.float64(11.071468810315926)}
# KL divergence: 0.00017475553292905428
# JS divergence: 3.722094656836355e-05
# Wasserstein: 5.789792981756502
# MMD: 0.00045593256987304387
# KS test: stat=0.0004, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.49391921457010546
# ----------------------------------------
# Value 0:
#   Original:   3160.729736, Value: 3160.729736 | Sign: 0 Exponent: 10001010 Mantissa: 10001011000101110101101
#   Compressed: 3160.750000, Value: 3160.750000 | Sign: 0 Exponent: 10001010 Mantissa: 10001011000110000000000
# Value 1:
#   Original:   29419.267578, Value: 29419.267578 | Sign: 0 Exponent: 10001101 Mantissa: 11001011101011010001001
#   Compressed: 29419.500000, Value: 29419.500000 | Sign: 0 Exponent: 10001101 Mantissa: 11001011101011100000000
# Value 2:
#   Original:   31330.224609, Value: 31330.224609 | Sign: 0 Exponent: 10001101 Mantissa: 11101001100010001110011
#   Compressed: 31330.000000, Value: 31330.000000 | Sign: 0 Exponent: 10001101 Mantissa: 11101001100010000000000
#
# === Compressed vs Original, nmantissa=15 ===
# Summary (original): {'mean': np.float32(30765.113), 'std': np.float32(36173.812), 'skew': np.float64(2.5236427783966064), 'kurtosis': np.float32(11.069621)}
# Summary (compressed): {'mean': np.float64(30765.116620242497), 'std': np.float64(36173.80781175644), 'skew': np.float64(2.5236403206082887), 'kurtosis': np.float64(11.069594396335821)}
# KL divergence: 4.5726276500620256e-14
# JS divergence: 1.1334727895263829e-14
# Wasserstein: 0.16999616810882617
# MMD: 0.000210484162678413
# KS test: stat=0.0001, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.5009069368833229
# ----------------------------------------
# Value 0:
#   Original:   55205.414062, Value: 55205.414062 | Sign: 0 Exponent: 10001110 Mantissa: 10101111010010101101010
#   Compressed: 57344.000000, Value: 57344.000000 | Sign: 0 Exponent: 10001110 Mantissa: 11000000000000000000000
# Value 1:
#   Original:   38766.433594, Value: 38766.433594 | Sign: 0 Exponent: 10001110 Mantissa: 00101110110111001101111
#   Compressed: 40960.000000, Value: 40960.000000 | Sign: 0 Exponent: 10001110 Mantissa: 01000000000000000000000
# Value 2:
#   Original:   39611.199219, Value: 39611.199219 | Sign: 0 Exponent: 10001110 Mantissa: 00110101011101100110011
#   Compressed: 40960.000000, Value: 40960.000000 | Sign: 0 Exponent: 10001110 Mantissa: 01000000000000000000000
#
# === Compressed vs Original, nmantissa=2 ===
# Summary (original): {'mean': np.float32(33555.43), 'std': np.float32(36517.46), 'skew': np.float64(2.513550281524658), 'kurtosis': np.float32(13.018484)}
# Summary (compressed): {'mean': np.float64(32695.126019529005), 'std': np.float64(35992.511650432774), 'skew': np.float64(2.5919317427311315), 'kurtosis': np.float64(14.040827593186009)}
# KL divergence: 1.6030160193178757
# JS divergence: 0.07599041915811332
# Wasserstein: 1771.260751302456
# MMD: 0.04652894588597438
# KS test: stat=0.0503, p=0.0000
# Classifier AUC (0.5 = indistinguishable): 0.5111022119965675
# ----------------------------------------
# Value 0:
#   Original:   55205.414062, Value: 55205.414062 | Sign: 0 Exponent: 10001110 Mantissa: 10101111010010101101010
#   Compressed: 53248.000000, Value: 53248.000000 | Sign: 0 Exponent: 10001110 Mantissa: 10100000000000000000000
# Value 1:
#   Original:   38766.433594, Value: 38766.433594 | Sign: 0 Exponent: 10001110 Mantissa: 00101110110111001101111
#   Compressed: 36864.000000, Value: 36864.000000 | Sign: 0 Exponent: 10001110 Mantissa: 00100000000000000000000
# Value 2:
#   Original:   39611.199219, Value: 39611.199219 | Sign: 0 Exponent: 10001110 Mantissa: 00110101011101100110011
#   Compressed: 40960.000000, Value: 40960.000000 | Sign: 0 Exponent: 10001110 Mantissa: 01000000000000000000000
#
# === Compressed vs Original, nmantissa=3 ===
# Summary (original): {'mean': np.float32(33555.43), 'std': np.float32(36517.46), 'skew': np.float64(2.513550281524658), 'kurtosis': np.float32(13.018484)}
# Summary (compressed): {'mean': np.float64(33162.75856787287), 'std': np.float64(36286.94888789146), 'skew': np.float64(2.551060832070591), 'kurtosis': np.float64(13.586850912092679)}
# KL divergence: 0.47448675847519084
# JS divergence: 0.025157564710072192
# Wasserstein: 889.704491374167
# MMD: 0.023332448649730216
# KS test: stat=0.0262, p=0.0000
# Classifier AUC (0.5 = indistinguishable): 0.5013632589049842
# ----------------------------------------
# Value 0:
#   Original:   55205.414062, Value: 55205.414062 | Sign: 0 Exponent: 10001110 Mantissa: 10101111010010101101010
#   Compressed: 55296.000000, Value: 55296.000000 | Sign: 0 Exponent: 10001110 Mantissa: 10110000000000000000000
# Value 1:
#   Original:   38766.433594, Value: 38766.433594 | Sign: 0 Exponent: 10001110 Mantissa: 00101110110111001101111
#   Compressed: 38912.000000, Value: 38912.000000 | Sign: 0 Exponent: 10001110 Mantissa: 00110000000000000000000
# Value 2:
#   Original:   39611.199219, Value: 39611.199219 | Sign: 0 Exponent: 10001110 Mantissa: 00110101011101100110011
#   Compressed: 39936.000000, Value: 39936.000000 | Sign: 0 Exponent: 10001110 Mantissa: 00111000000000000000000
#
# === Compressed vs Original, nmantissa=5 ===
# Summary (original): {'mean': np.float32(33555.43), 'std': np.float32(36517.46), 'skew': np.float64(2.513550281524658), 'kurtosis': np.float32(13.018484)}
# Summary (compressed): {'mean': np.float64(33472.56366073138), 'std': np.float64(36491.03542704651), 'skew': np.float64(2.523102931824617), 'kurtosis': np.float64(13.16590625191236)}
# KL divergence: 0.006299128817389459
# JS divergence: 0.0012036126216769553
# Wasserstein: 221.4020226697873
# MMD: 0.006175190573920293
# KS test: stat=0.0071, p=0.5194
# Classifier AUC (0.5 = indistinguishable): 0.49329716375480437
# ----------------------------------------
# Value 0:
#   Original:   55205.414062, Value: 55205.414062 | Sign: 0 Exponent: 10001110 Mantissa: 10101111010010101101010
#   Compressed: 55200.000000, Value: 55200.000000 | Sign: 0 Exponent: 10001110 Mantissa: 10101111010000000000000
# Value 1:
#   Original:   38766.433594, Value: 38766.433594 | Sign: 0 Exponent: 10001110 Mantissa: 00101110110111001101111
#   Compressed: 38752.000000, Value: 38752.000000 | Sign: 0 Exponent: 10001110 Mantissa: 00101110110000000000000
# Value 2:
#   Original:   39611.199219, Value: 39611.199219 | Sign: 0 Exponent: 10001110 Mantissa: 00110101011101100110011
#   Compressed: 39616.000000, Value: 39616.000000 | Sign: 0 Exponent: 10001110 Mantissa: 00110101100000000000000
#
# === Compressed vs Original, nmantissa=10 ===
# Summary (original): {'mean': np.float32(33555.43), 'std': np.float32(36517.46), 'skew': np.float64(2.513550281524658), 'kurtosis': np.float32(13.018484)}
# Summary (compressed): {'mean': np.float64(33550.37005552364), 'std': np.float64(36508.16217688198), 'skew': np.float64(2.5141224895179275), 'kurtosis': np.float64(13.025969466869363)}
# KL divergence: 3.781806352687725e-05
# JS divergence: 9.419810711410521e-06
# Wasserstein: 9.267319447186736
# MMD: 0.00047789614308983117
# KS test: stat=0.0005, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.4962611717060075
# ----------------------------------------
# Value 0:
#   Original:   55205.414062, Value: 55205.414062 | Sign: 0 Exponent: 10001110 Mantissa: 10101111010010101101010
#   Compressed: 55205.000000, Value: 55205.000000 | Sign: 0 Exponent: 10001110 Mantissa: 10101111010010100000000
# Value 1:
#   Original:   38766.433594, Value: 38766.433594 | Sign: 0 Exponent: 10001110 Mantissa: 00101110110111001101111
#   Compressed: 38766.000000, Value: 38766.000000 | Sign: 0 Exponent: 10001110 Mantissa: 00101110110111000000000
# Value 2:
#   Original:   39611.199219, Value: 39611.199219 | Sign: 0 Exponent: 10001110 Mantissa: 00110101011101100110011
#   Compressed: 39611.000000, Value: 39611.000000 | Sign: 0 Exponent: 10001110 Mantissa: 00110101011101100000000
#
# === Compressed vs Original, nmantissa=15 ===
# Summary (original): {'mean': np.float32(33555.43), 'std': np.float32(36517.46), 'skew': np.float64(2.513550281524658), 'kurtosis': np.float32(13.018484)}
# Summary (compressed): {'mean': np.float64(33555.42943351522), 'std': np.float64(36517.45639843025), 'skew': np.float64(2.513543935805852), 'kurtosis': np.float64(13.018346912758673)}
# KL divergence: 5.085061313560501e-06
# JS divergence: 1.2936533430851122e-06
# Wasserstein: 0.18392095359467758
# MMD: 0.00022289088721995799
# KS test: stat=0.0001, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.4945159360495437
# ----------------------------------------

# %%
for compressed, residual in dataloader:
    compressed = compressed.squeeze()
    residual = residual.squeeze()
    original = compressed + residual
    for nmantissa in [2, 3, 5, 10, 15]:
        compressed_new = np.array([reduce_float_precision(i, nmantissa=nmantissa) for i in original])
        triage(np.log10(original.numpy()), np.log10(compressed_new), name=f"Compressed vs Original, nmantissa={nmantissa}")
        print("-"*40)
# Out:
# === Compressed vs Original, nmantissa=2 ===
# Summary (original): {'mean': np.float32(3.992496), 'std': np.float32(0.4559511), 'skew': np.float64(0.5765568614006042), 'kurtosis': np.float32(-0.87060547)}
# Summary (compressed): {'mean': np.float64(3.991039458775161), 'std': np.float64(0.45595377696340494), 'skew': np.float64(0.5767835115544582), 'kurtosis': np.float64(-0.8589052773938399)}
# KL divergence: 0.19503706721254777
# JS divergence: 0.03283681077811146
# Wasserstein: 0.0031508548659701916
# MMD: 1.9032895977044717e-06
# KS test: stat=0.0145, p=0.2424
# Classifier AUC (0.5 = indistinguishable): 0.5021385483634638
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=3 ===
# Summary (original): {'mean': np.float32(3.992496), 'std': np.float32(0.4559511), 'skew': np.float64(0.5765568614006042), 'kurtosis': np.float32(-0.87060547)}
# Summary (compressed): {'mean': np.float64(3.991039458775161), 'std': np.float64(0.45595377696340494), 'skew': np.float64(0.5767835115544582), 'kurtosis': np.float64(-0.8589052773938399)}
# KL divergence: 0.19503706721254777
# JS divergence: 0.03283681077811146
# Wasserstein: 0.0031508548659701916
# MMD: 1.9032895977044717e-06
# KS test: stat=0.0145, p=0.2424
# Classifier AUC (0.5 = indistinguishable): 0.49801184944371624
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=5 ===
# Summary (original): {'mean': np.float32(3.992496), 'std': np.float32(0.4559511), 'skew': np.float64(0.5765568614006042), 'kurtosis': np.float32(-0.87060547)}
# Summary (compressed): {'mean': np.float64(3.991039458775161), 'std': np.float64(0.45595377696340494), 'skew': np.float64(0.5767835115544582), 'kurtosis': np.float64(-0.8589052773938399)}
# KL divergence: 0.19503706721254777
# JS divergence: 0.03283681077811146
# Wasserstein: 0.0031508548659701916
# MMD: 1.9032895977044717e-06
# KS test: stat=0.0145, p=0.2424
# Classifier AUC (0.5 = indistinguishable): 0.4984800857367102
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=10 ===
# Summary (original): {'mean': np.float32(3.992496), 'std': np.float32(0.4559511), 'skew': np.float64(0.5765568614006042), 'kurtosis': np.float32(-0.87060547)}
# Summary (compressed): {'mean': np.float64(3.9924350620102134), 'std': np.float64(0.4560205152446219), 'skew': np.float64(0.5759674926233617), 'kurtosis': np.float64(-0.8699154605821007)}
# KL divergence: 0.18708532483099272
# JS divergence: 0.029313196587133668
# Wasserstein: 0.000120188435356266
# MMD: 4.39066822455203e-07
# KS test: stat=0.0010, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.49308823028150844
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=15 ===
# Summary (original): {'mean': np.float32(3.992496), 'std': np.float32(0.4559511), 'skew': np.float64(0.5765568614006042), 'kurtosis': np.float32(-0.87060547)}
# Summary (compressed): {'mean': np.float64(3.992496012483722), 'std': np.float64(0.45595101064109406), 'skew': np.float64(0.5765561984188637), 'kurtosis': np.float64(-0.8706063010314598)}
# KL divergence: 1.408914119972904e-06
# JS divergence: 3.5230696745073796e-07
# Wasserstein: 2.3658677945009547e-06
# MMD: 4.319934270302639e-07
# KS test: stat=0.0003, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.4966631385709398
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=2 ===
# Summary (original): {'mean': np.float32(4.1446724), 'std': np.float32(0.48218346), 'skew': np.float64(-0.012344914488494396), 'kurtosis': np.float32(-1.2388875)}
# Summary (compressed): {'mean': np.float64(4.142859693068855), 'std': np.float64(0.4821725785988742), 'skew': np.float64(-0.009414555595635221), 'kurtosis': np.float64(-1.2264586834197075)}
# KL divergence: 0.02325955456551436
# JS divergence: 0.004264041553214814
# Wasserstein: 0.0035126095892707735
# MMD: 3.7286166241212726e-06
# KS test: stat=0.0121, p=0.6895
# Classifier AUC (0.5 = indistinguishable): 0.49495608024870796
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=3 ===
# Summary (original): {'mean': np.float32(4.1446724), 'std': np.float32(0.48218346), 'skew': np.float64(-0.012344914488494396), 'kurtosis': np.float32(-1.2388875)}
# Summary (compressed): {'mean': np.float64(4.142859693068855), 'std': np.float64(0.4821725785988742), 'skew': np.float64(-0.009414555595635221), 'kurtosis': np.float64(-1.2264586834197075)}
# KL divergence: 0.02325955456551436
# JS divergence: 0.004264041553214814
# Wasserstein: 0.0035126095892707735
# MMD: 3.7286166241212726e-06
# KS test: stat=0.0121, p=0.6895
# Classifier AUC (0.5 = indistinguishable): 0.4897114556774549
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=5 ===
# Summary (original): {'mean': np.float32(4.1446724), 'std': np.float32(0.48218346), 'skew': np.float64(-0.012344914488494396), 'kurtosis': np.float32(-1.2388875)}
# Summary (compressed): {'mean': np.float64(4.142859693068855), 'std': np.float64(0.4821725785988742), 'skew': np.float64(-0.009414555595635221), 'kurtosis': np.float64(-1.2264586834197075)}
# KL divergence: 0.02325955456551436
# JS divergence: 0.004264041553214814
# Wasserstein: 0.0035126095892707735
# MMD: 3.7286166241212726e-06
# KS test: stat=0.0121, p=0.6895
# Classifier AUC (0.5 = indistinguishable): 0.5031367625712733
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=10 ===
# Summary (original): {'mean': np.float32(4.1446724), 'std': np.float32(0.48218346), 'skew': np.float64(-0.012344914488494396), 'kurtosis': np.float32(-1.2388875)}
# Summary (compressed): {'mean': np.float64(4.144626906561865), 'std': np.float64(0.4822163135989546), 'skew': np.float64(-0.012252747613367998), 'kurtosis': np.float64(-1.239190766535882)}
# KL divergence: 5.407176695442025e-05
# JS divergence: 1.3532147671712856e-05
# Wasserstein: 0.00010595924235278349
# MMD: 1.3096032080994746e-07
# KS test: stat=0.0012, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.4972980978719752
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=15 ===
# Summary (original): {'mean': np.float32(4.1446724), 'std': np.float32(0.48218346), 'skew': np.float64(-0.012344914488494396), 'kurtosis': np.float32(-1.2388875)}
# Summary (compressed): {'mean': np.float64(4.14467243758174), 'std': np.float64(0.48218337207565864), 'skew': np.float64(-0.012346088360688881), 'kurtosis': np.float64(-1.2388879615616888)}
# KL divergence: 4.8769779596236935e-06
# JS divergence: 1.2148230566831935e-06
# Wasserstein: 2.3759389899420153e-06
# MMD: 1.2388644021754658e-07
# KS test: stat=0.0003, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.5
# ----------------------------------------
# /home/kanbina/code/dct_flow/.venv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:586: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   res = hypotest_fun_out(*samples, **kwds)
# === Compressed vs Original, nmantissa=2 ===
# Summary (original): {'mean': np.float32(4.2097564), 'std': np.float32(0.5127048), 'skew': np.float64(0.07886702567338943), 'kurtosis': np.float32(-1.1666573)}
# Summary (compressed): {'mean': np.float64(4.208176450680476), 'std': np.float64(0.5128520846835353), 'skew': np.float64(0.08036117470414714), 'kurtosis': np.float64(-1.1652974576912163)}
# KL divergence: 0.025709718041742866
# JS divergence: 0.0061159352572704075
# Wasserstein: 0.003043748845682501
# MMD: 1.978988609652177e-06
# KS test: stat=0.0082, p=0.1149
# Classifier AUC (0.5 = indistinguishable): 0.5020281753658332
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=3 ===
# Summary (original): {'mean': np.float32(4.2097564), 'std': np.float32(0.5127048), 'skew': np.float64(0.07886702567338943), 'kurtosis': np.float32(-1.1666573)}
# Summary (compressed): {'mean': np.float64(4.208176450680476), 'std': np.float64(0.5128520846835353), 'skew': np.float64(0.08036117470414714), 'kurtosis': np.float64(-1.1652974576912163)}
# KL divergence: 0.025709718041742866
# JS divergence: 0.0061159352572704075
# Wasserstein: 0.003043748845682501
# MMD: 1.978988609652177e-06
# KS test: stat=0.0082, p=0.1149
# Classifier AUC (0.5 = indistinguishable): 0.4981951628827597
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=5 ===
# Summary (original): {'mean': np.float32(4.2097564), 'std': np.float32(0.5127048), 'skew': np.float64(0.07886702567338943), 'kurtosis': np.float32(-1.1666573)}
# Summary (compressed): {'mean': np.float64(4.208176450680476), 'std': np.float64(0.5128520846835353), 'skew': np.float64(0.08036117470414714), 'kurtosis': np.float64(-1.1652974576912163)}
# KL divergence: 0.025709718041742866
# JS divergence: 0.0061159352572704075
# Wasserstein: 0.003043748845682501
# MMD: 1.978988609652177e-06
# KS test: stat=0.0082, p=0.1149
# Classifier AUC (0.5 = indistinguishable): 0.4996280364138803
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=10 ===
# Summary (original): {'mean': np.float32(4.2097564), 'std': np.float32(0.5127048), 'skew': np.float64(0.07886702567338943), 'kurtosis': np.float32(-1.1666573)}
# Summary (compressed): {'mean': np.float64(4.2097211320288235), 'std': np.float64(0.5127353457163583), 'skew': np.float64(0.07866652837797844), 'kurtosis': np.float64(-1.166079441525659)}
# KL divergence: 0.010243029623195175
# JS divergence: 0.002362414517828961
# Wasserstein: 9.673241446619741e-05
# MMD: 3.9708247356884385e-07
# KS test: stat=0.0004, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.499567972675461
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=15 ===
# Summary (original): {'mean': np.float32(4.2097564), 'std': np.float32(0.5127048), 'skew': np.float64(0.07886702567338943), 'kurtosis': np.float32(-1.1666573)}
# Summary (compressed): {'mean': np.float64(4.209756564108419), 'std': np.float64(0.5127047590511741), 'skew': np.float64(0.07886499347333252), 'kurtosis': np.float64(-1.1666582081389907)}
# KL divergence: 9.004743860503718e-08
# JS divergence: 2.251196267456586e-08
# Wasserstein: 2.3895856451169844e-06
# MMD: 3.8985690875570356e-07
# KS test: stat=0.0001, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.4948771511494329
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=2 ===
# Summary (original): {'mean': np.float32(4.276566), 'std': np.float32(0.4939141), 'skew': np.float64(-0.08247683942317963), 'kurtosis': np.float32(-1.0728544)}
# Summary (compressed): {'mean': np.float64(4.274910654683502), 'std': np.float64(0.49437809939820077), 'skew': np.float64(-0.08080013213559649), 'kurtosis': np.float64(-1.069923041663941)}
# KL divergence: 0.013278285502981543
# JS divergence: 0.003171738382975471
# Wasserstein: 0.003166705513905957
# MMD: 2.367308953088454e-06
# KS test: stat=0.0071, p=0.5194
# Classifier AUC (0.5 = indistinguishable): 0.5
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=3 ===
# Summary (original): {'mean': np.float32(4.276566), 'std': np.float32(0.4939141), 'skew': np.float64(-0.08247683942317963), 'kurtosis': np.float32(-1.0728544)}
# Summary (compressed): {'mean': np.float64(4.274910654683502), 'std': np.float64(0.49437809939820077), 'skew': np.float64(-0.08080013213559649), 'kurtosis': np.float64(-1.069923041663941)}
# KL divergence: 0.013278285502981543
# JS divergence: 0.003171738382975471
# Wasserstein: 0.003166705513905957
# MMD: 2.367308953088454e-06
# KS test: stat=0.0071, p=0.5194
# Classifier AUC (0.5 = indistinguishable): 0.4990926433123562
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=5 ===
# Summary (original): {'mean': np.float32(4.276566), 'std': np.float32(0.4939141), 'skew': np.float64(-0.08247683942317963), 'kurtosis': np.float32(-1.0728544)}
# Summary (compressed): {'mean': np.float64(4.274910654683502), 'std': np.float64(0.49437809939820077), 'skew': np.float64(-0.08080013213559649), 'kurtosis': np.float64(-1.069923041663941)}
# KL divergence: 0.013278285502981543
# JS divergence: 0.003171738382975471
# Wasserstein: 0.003166705513905957
# MMD: 2.367308953088454e-06
# KS test: stat=0.0071, p=0.5194
# Classifier AUC (0.5 = indistinguishable): 0.49725950355648696
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=10 ===
# Summary (original): {'mean': np.float32(4.276566), 'std': np.float32(0.4939141), 'skew': np.float64(-0.08247683942317963), 'kurtosis': np.float32(-1.0728544)}
# Summary (compressed): {'mean': np.float64(4.276542941513191), 'std': np.float64(0.4938813507107336), 'skew': np.float64(-0.08263162164306721), 'kurtosis': np.float64(-1.0729074481845464)}
# KL divergence: 1.80982576923376e-05
# JS divergence: 4.525297206462096e-06
# Wasserstein: 9.093826656256412e-05
# MMD: -3.4596018649857285e-07
# KS test: stat=0.0005, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.5
# ----------------------------------------
#
# === Compressed vs Original, nmantissa=15 ===
# Summary (original): {'mean': np.float32(4.276566), 'std': np.float32(0.4939141), 'skew': np.float64(-0.08247683942317963), 'kurtosis': np.float32(-1.0728544)}
# Summary (compressed): {'mean': np.float64(4.276565740085661), 'std': np.float64(0.4939140644769127), 'skew': np.float64(-0.08247616195795893), 'kurtosis': np.float64(-1.072854716972825)}
# KL divergence: 3.584732071796663e-07
# JS divergence: 8.961867981159455e-08
# Wasserstein: 2.3842211670427843e-06
# MMD: -3.528506387073804e-07
# KS test: stat=0.0001, p=1.0000
# Classifier AUC (0.5 = indistinguishable): 0.5
# ----------------------------------------
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
